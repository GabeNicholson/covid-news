# %%
import pandas    
pandas.__version__
# Out:
# '1.4.4'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from datetime import date
from scipy.stats import permutation_test
import plotly.express as px

pd.options.mode.chained_assignment = None
sns.set_style('dark')

# The publisher page and sentiment information are split up because I am using two ProQuest accounts (double the GPU power).
us_apr_feb2021_publisher_page_df = pd.read_csv('csv/us_apr-feb2021_publisher_page_df.csv', index_col=[0])
pre_page_df = us_apr_feb2021_publisher_page_df[['page', 'total_page', 'page_prediction']]
pre_publisher_df = us_apr_feb2021_publisher_page_df[['publisher_name', 'total_published', 'publisher_prediction']]

publisher_page_us_mar_apr2022 = pd.read_csv('csv/publisher_page_us-mar-apr2022.csv', index_col=[0])
post_page_df = publisher_page_us_mar_apr2022[['page', 'total_page', 'page_prediction']]
post_publisher_df = publisher_page_us_mar_apr2022[['publisher_name', 'total_published', 'publisher_prediction']]

publisher_df = pd.merge(pre_publisher_df, post_publisher_df, on='publisher_name', how='inner')
page_df = pd.merge(pre_page_df, post_page_df, on='page', how='inner')

page_df['sentiment'] = page_df.eval("(page_prediction_x + page_prediction_y) / (total_page_x + total_page_y)")
page_df = page_df[['page', 'sentiment']]
publisher_df['sentiment'] = publisher_df.eval('(publisher_prediction_x + publisher_prediction_y) / (total_published_y + total_published_x)')
publisher_df = publisher_df[['publisher_name', 'sentiment']]
publisher_df = publisher_df[publisher_df['publisher_name'].isin(pre_publisher_df[:20]['publisher_name'])].round(2)
publisher_df.sort_values(by='sentiment', inplace=True)

# %%
# publisher_df.to_csv('dashboard/publisher_df.csv')

# %%
plot_pub = publisher_df.head(10)
plot_pub['inverse_sentiment'] = plot_pub['sentiment'] * -1
fig = px.bar(plot_pub, x='publisher_name', y="inverse_sentiment")
fig

# %%
# Covid Health Data from OurWorldinData
health_data_df = pd.read_csv('csv/cleaned_health_data.csv', parse_dates=['date'], index_col=[0,1])
us_health_data = health_data_df.loc['United States']
us_sentim_2021_df = pd.read_csv('csv/us_apr-feb2021.csv', index_col=[0], parse_dates=['date'])
us_sentim_2022_df = pd.read_csv('csv/us-mar-apr2022.csv', index_col=[0], parse_dates=['date'])
NEW_us_sentim_2022_df = pd.read_csv('csv/us_covid_april_2021-april_2022.csv', parse_dates=['date'])
df = pd.concat([us_sentim_2021_df,us_sentim_2022_df])

health_data_df = us_health_data[(us_health_data.date >= df.date.min()) & (us_health_data.date <= df.date.max())]
df = df.merge(health_data_df, on='date')
# df = df.set_index('date', drop=False)
# # Smoothing trends to help with the inherent noise of sentiment calculations.
df['smoothed_prediction'] = df.prediction.rolling(window=4, center=True, win_type='gaussian').mean(std=2)
df['smoothed_articles_per_day'] = df.articles_per_day.rolling(window=5, center=True, win_type='gaussian').mean(std=3)

NEW_df = pd.concat([us_sentim_2021_df,NEW_us_sentim_2022_df])
NEW_df['smoothed_prediction'] = NEW_df.prediction.rolling(window=4, center=True, win_type='gaussian').mean(std=2)
NEW_df['smoothed_articles_per_day'] = NEW_df.articles_per_day.rolling(window=5, center=True, win_type='gaussian').mean(std=3)

df = df.round(4)

# %%
print(NEW_us_sentim_2022_df.prediction.mean())
print(us_sentim_2022_df.prediction.mean())
# Out:
# -0.12614013825499265
# -0.1416459804759672

# %%
df.head()
# Out:
#         date  prediction  articles_per_day  stringency_index  positive_rate  \
# 0 2020-04-01     -0.2856            1447.0             72.69          0.199
# 1 2020-04-02     -0.2604            1488.0             72.69          0.204
# 2 2020-04-03     -0.2372            1393.0             72.69          0.207
# 3 2020-04-04     -0.3091             915.0             72.69          0.209
# 4 2020-04-05     -0.2433            1064.0             72.69          0.210
#
#    new_cases_smoothed  new_deaths_smoothed  weekly_hosp_admissions  \
# 0           22722.429              804.286                     NaN
# 1           24787.429              966.000                     NaN
# 2           26766.571             1095.429                     NaN
# 3           28132.000             1225.000                     NaN
# 4           29939.000             1377.571                     NaN
#
#    new_vaccinations_smoothed  new_people_vaccinated_smoothed  new_cases  \
# 0                        NaN                             NaN    35819.0
# 1                        NaN                             NaN    32276.0
# 2                        NaN                             NaN    32445.0
# 3                        NaN                             NaN    31722.0
# 4                        NaN                             NaN    28776.0
#
#    smoothed_prediction  smoothed_articles_per_day
# 0                  NaN                        NaN
# 1                  NaN                        NaN
# 2              -0.2701                  1263.3641
# 3              -0.2638                  1177.0858
# 4              -0.2633                  1129.2987

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=df['date'], y=df['smoothed_prediction'], name="yaxis data"),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=NEW_df['date'], y=NEW_df['smoothed_prediction'], name="yaxis2 data"),
    secondary_y=False, 
)

# fig.add_trace(
#     go.Scatter(x=df['date'], y=df['smoothed_articles_per_day'], name="yaxis2 data"),
#     secondary_y=False, 
# )
fig.update_layout(
    # margin=dict(l=20, r=20, t=70, b=80),
    height=750
)

# %% [markdown]
# Stationarity means that the statistical properties of a time series i.e. mean, variance and covariance do not change over time. Many statistical models require the series to be stationary to make effective and precise predictions.
#
# The two test being used to test for stationarity is the Augmented Dickey Fuller (“ADF”) test and Kwiatkowski-Phillips-Schmidt-Shin (“KPSS”) test.

# %%
from statsmodels.tsa.stattools import adfuller, kpss, grangercausalitytests

# %% [markdown]
# **ADF test** is used to determine the presence of unit root in the series, and hence helps in understand if the series is stationary or not. The null and alternate hypothesis of this test are:
#
# Null Hypothesis: The series has a unit root.
#
# Alternate Hypothesis: The series has no unit root.
#
# If the null hypothesis in failed to be rejected, this test may provide evidence that the series is non-stationary.

# %%
df.columns
# Out:
# Index(['date', 'prediction', 'articles_per_day', 'stringency_index',
#        'positive_rate', 'new_cases_smoothed', 'new_deaths_smoothed',
#        'weekly_hosp_admissions', 'new_vaccinations_smoothed',
#        'new_people_vaccinated_smoothed', 'new_cases', 'smoothed_prediction',
#        'smoothed_articles_per_day'],
#       dtype='object')

# %%
def run_adf_test(column):
    adf_results = adfuller(column, autolag="AIC")
    return pd.Series(adf_results[0:4],index=[
                "Test Statistic",
                "p-value",
                "#Lags Used",
                "Number of Observations Used"])

def kpss_test(timeseries):
    print("Results of KPSS Test:")
    kpsstest = kpss(timeseries, regression="c", nlags="auto")
    kpss_output = pd.Series(
        kpsstest[0:3], index=["Test Statistic", "p-value", "Lags Used"]
    )
    for key, value in kpsstest[3].items():
        kpss_output["Critical Value (%s)" % key] = value
    print(kpss_output)

# %%
for col_name in ['prediction', 'smoothed_prediction', 'positive_rate', 'new_cases_smoothed',
                 'smoothed_articles_per_day', 'weekly_hosp_admissions']:
    print(f"{col_name}: {round(run_adf_test(df[col_name].dropna())[1],3)}")
# Out:
# prediction: 0.109
# smoothed_prediction: 0.066
# positive_rate: 0.0
# new_cases_smoothed: 0.015
# smoothed_articles_per_day: 0.013
# weekly_hosp_admissions: 0.02

# %%
for col_name in ['prediction', 'smoothed_prediction', 'positive_rate', 'new_cases_smoothed',
                 'smoothed_articles_per_day', 'weekly_hosp_admissions']:
    print(f"{col_name}: {round(kpss(df[col_name].dropna())[1],3)}");
# Out:
# prediction: 0.027
# smoothed_prediction: 0.028
# positive_rate: 0.1
# new_cases_smoothed: 0.03
# smoothed_articles_per_day: 0.01
# weekly_hosp_admissions: 0.1
# /Users/gabriel/miniforge3/envs/covid-news/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#
# /Users/gabriel/miniforge3/envs/covid-news/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#
# /Users/gabriel/miniforge3/envs/covid-news/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.

# %%
df.corr().round(2)
# Out:
#                                 prediction  articles_per_day  \
# prediction                            1.00             -0.25
# articles_per_day                     -0.25              1.00
# stringency_index                     -0.13              0.64
# positive_rate                        -0.43              0.46
# new_cases_smoothed                   -0.22             -0.01
# new_deaths_smoothed                   0.06              0.22
# weekly_hosp_admissions               -0.29              0.41
# new_vaccinations_smoothed             0.32              0.27
# new_people_vaccinated_smoothed        0.33              0.37
# new_cases                            -0.22              0.05
# smoothed_prediction                   0.95             -0.30
# smoothed_articles_per_day            -0.31              0.95
#
#                                 stringency_index  positive_rate  \
# prediction                                 -0.13          -0.43
# articles_per_day                            0.64           0.46
# stringency_index                            1.00           0.15
# positive_rate                               0.15           1.00
# new_cases_smoothed                         -0.14           0.79
# new_deaths_smoothed                         0.27           0.47
# weekly_hosp_admissions                      0.26           0.88
# new_vaccinations_smoothed                   0.37          -0.14
# new_people_vaccinated_smoothed              0.53          -0.16
# new_cases                                  -0.12           0.74
# smoothed_prediction                        -0.14          -0.46
# smoothed_articles_per_day                   0.70           0.49
#
#                                 new_cases_smoothed  new_deaths_smoothed  \
# prediction                                   -0.22                 0.06
# articles_per_day                             -0.01                 0.22
# stringency_index                             -0.14                 0.27
# positive_rate                                 0.79                 0.47
# new_cases_smoothed                            1.00                 0.47
# new_deaths_smoothed                           0.47                 1.00
# weekly_hosp_admissions                        0.86                 0.74
# new_vaccinations_smoothed                    -0.11                -0.09
# new_people_vaccinated_smoothed               -0.16                 0.01
# new_cases                                     0.91                 0.39
# smoothed_prediction                          -0.24                 0.06
# smoothed_articles_per_day                    -0.01                 0.25
#
#                                 weekly_hosp_admissions  \
# prediction                                       -0.29
# articles_per_day                                  0.41
# stringency_index                                  0.26
# positive_rate                                     0.88
# new_cases_smoothed                                0.86
# new_deaths_smoothed                               0.74
# weekly_hosp_admissions                            1.00
# new_vaccinations_smoothed                        -0.13
# new_people_vaccinated_smoothed                   -0.07
# new_cases                                         0.77
# smoothed_prediction                              -0.32
# smoothed_articles_per_day                         0.47
#
#                                 new_vaccinations_smoothed  \
# prediction                                           0.32
# articles_per_day                                     0.27
# stringency_index                                     0.37
# positive_rate                                       -0.14
# new_cases_smoothed                                  -0.11
# new_deaths_smoothed                                 -0.09
# weekly_hosp_admissions                              -0.13
# new_vaccinations_smoothed                            1.00
# new_people_vaccinated_smoothed                       0.90
# new_cases                                           -0.09
# smoothed_prediction                                  0.35
# smoothed_articles_per_day                            0.30
#
#                                 new_people_vaccinated_smoothed  new_cases  \
# prediction                                                0.33      -0.22
# articles_per_day                                          0.37       0.05
# stringency_index                                          0.53      -0.12
# positive_rate                                            -0.16       0.74
# new_cases_smoothed                                       -0.16       0.91
# new_deaths_smoothed                                       0.01       0.39
# weekly_hosp_admissions                                   -0.07       0.77
# new_vaccinations_smoothed                                 0.90      -0.09
# new_people_vaccinated_smoothed                            1.00      -0.14
# new_cases                                                -0.14       1.00
# smoothed_prediction                                       0.36      -0.25
# smoothed_articles_per_day                                 0.42       0.03
#
#                                 smoothed_prediction  smoothed_articles_per_day
# prediction                                     0.95                      -0.31
# articles_per_day                              -0.30                       0.95
# stringency_index                              -0.14                       0.70
# positive_rate                                 -0.46                       0.49
# new_cases_smoothed                            -0.24                      -0.01
# new_deaths_smoothed                            0.06                       0.25
# weekly_hosp_admissions                        -0.32                       0.47
# new_vaccinations_smoothed                      0.35                       0.30
# new_people_vaccinated_smoothed                 0.36                       0.42
# new_cases                                     -0.25                       0.03
# smoothed_prediction                            1.00                      -0.34
# smoothed_articles_per_day                     -0.34                       1.00

# %%
df.diff().corr('spearman').round(2)
# Out:
#                                 prediction  articles_per_day  \
# prediction                            1.00              0.16
# articles_per_day                      0.16              1.00
# stringency_index                     -0.01              0.03
# positive_rate                        -0.08              0.04
# new_cases_smoothed                   -0.05              0.09
# new_deaths_smoothed                   0.02              0.06
# weekly_hosp_admissions               -0.04              0.05
# new_vaccinations_smoothed            -0.03              0.04
# new_people_vaccinated_smoothed       -0.04              0.03
# new_cases                             0.10              0.16
# smoothed_prediction                   0.28              0.27
# smoothed_articles_per_day             0.21              0.67
#
#                                 stringency_index  positive_rate  \
# prediction                                 -0.01          -0.08
# articles_per_day                            0.03           0.04
# stringency_index                            1.00           0.02
# positive_rate                               0.02           1.00
# new_cases_smoothed                          0.02           0.54
# new_deaths_smoothed                        -0.05           0.09
# weekly_hosp_admissions                      0.04           0.61
# new_vaccinations_smoothed                   0.16           0.09
# new_people_vaccinated_smoothed              0.16           0.15
# new_cases                                  -0.03           0.07
# smoothed_prediction                        -0.03          -0.15
# smoothed_articles_per_day                  -0.00           0.09
#
#                                 new_cases_smoothed  new_deaths_smoothed  \
# prediction                                   -0.05                 0.02
# articles_per_day                              0.09                 0.06
# stringency_index                              0.02                -0.05
# positive_rate                                 0.54                 0.09
# new_cases_smoothed                            1.00                 0.43
# new_deaths_smoothed                           0.43                 1.00
# weekly_hosp_admissions                        0.70                 0.37
# new_vaccinations_smoothed                     0.23                 0.13
# new_people_vaccinated_smoothed                0.23                 0.08
# new_cases                                     0.20                 0.12
# smoothed_prediction                          -0.06                 0.03
# smoothed_articles_per_day                     0.08                 0.05
#
#                                 weekly_hosp_admissions  \
# prediction                                       -0.04
# articles_per_day                                  0.05
# stringency_index                                  0.04
# positive_rate                                     0.61
# new_cases_smoothed                                0.70
# new_deaths_smoothed                               0.37
# weekly_hosp_admissions                            1.00
# new_vaccinations_smoothed                         0.14
# new_people_vaccinated_smoothed                    0.17
# new_cases                                         0.07
# smoothed_prediction                              -0.07
# smoothed_articles_per_day                         0.04
#
#                                 new_vaccinations_smoothed  \
# prediction                                          -0.03
# articles_per_day                                     0.04
# stringency_index                                     0.16
# positive_rate                                        0.09
# new_cases_smoothed                                   0.23
# new_deaths_smoothed                                  0.13
# weekly_hosp_admissions                               0.14
# new_vaccinations_smoothed                            1.00
# new_people_vaccinated_smoothed                       0.81
# new_cases                                            0.06
# smoothed_prediction                                 -0.06
# smoothed_articles_per_day                            0.01
#
#                                 new_people_vaccinated_smoothed  new_cases  \
# prediction                                               -0.04       0.10
# articles_per_day                                          0.03       0.16
# stringency_index                                          0.16      -0.03
# positive_rate                                             0.15       0.07
# new_cases_smoothed                                        0.23       0.20
# new_deaths_smoothed                                       0.08       0.12
# weekly_hosp_admissions                                    0.17       0.07
# new_vaccinations_smoothed                                 0.81       0.06
# new_people_vaccinated_smoothed                            1.00       0.07
# new_cases                                                 0.07       1.00
# smoothed_prediction                                      -0.10       0.15
# smoothed_articles_per_day                                 0.01       0.23
#
#                                 smoothed_prediction  smoothed_articles_per_day
# prediction                                     0.28                       0.21
# articles_per_day                               0.27                       0.67
# stringency_index                              -0.03                      -0.00
# positive_rate                                 -0.15                       0.09
# new_cases_smoothed                            -0.06                       0.08
# new_deaths_smoothed                            0.03                       0.05
# weekly_hosp_admissions                        -0.07                       0.04
# new_vaccinations_smoothed                     -0.06                       0.01
# new_people_vaccinated_smoothed                -0.10                       0.01
# new_cases                                      0.15                       0.23
# smoothed_prediction                            1.00                       0.34
# smoothed_articles_per_day                      0.34                       1.00

# %%
df.head()
# Out:
#         date  prediction  articles_per_day  stringency_index  positive_rate  \
# 0 2020-04-01     -0.2856            1447.0             72.69          0.199
# 1 2020-04-02     -0.2604            1488.0             72.69          0.204
# 2 2020-04-03     -0.2372            1393.0             72.69          0.207
# 3 2020-04-04     -0.3091             915.0             72.69          0.209
# 4 2020-04-05     -0.2433            1064.0             72.69          0.210
#
#    new_cases_smoothed  new_deaths_smoothed  weekly_hosp_admissions  \
# 0           22722.429              804.286                     NaN
# 1           24787.429              966.000                     NaN
# 2           26766.571             1095.429                     NaN
# 3           28132.000             1225.000                     NaN
# 4           29939.000             1377.571                     NaN
#
#    new_vaccinations_smoothed  new_people_vaccinated_smoothed  new_cases  \
# 0                        NaN                             NaN    35819.0
# 1                        NaN                             NaN    32276.0
# 2                        NaN                             NaN    32445.0
# 3                        NaN                             NaN    31722.0
# 4                        NaN                             NaN    28776.0
#
#    smoothed_prediction  smoothed_articles_per_day
# 0                  NaN                        NaN
# 1                  NaN                        NaN
# 2              -0.2701                  1263.3641
# 3              -0.2638                  1177.0858
# 4              -0.2633                  1129.2987

# %%
df.rename({'prediction':'Sentiment Score', 'positive_rate': 'Covid Positive Rate', 'smoothed_prediction':'Smoothed Sentiment Score'}, axis=1, inplace=True)
relevant_cols = ['date','Sentiment Score','Smoothed Sentiment Score' ,'articles_per_day', 'smoothed_articles_per_day', 
             'Covid Positive Rate', 'new_deaths_smoothed', 'weekly_hosp_admissions', 'new_vaccinations_smoothed', 'stringency_index']
df = df[relevant_cols]

# %%
df.head()
# Out:
#         date  Sentiment Score  Smoothed Sentiment Score  articles_per_day  \
# 0 2020-04-01          -0.2856                       NaN            1447.0
# 1 2020-04-02          -0.2604                       NaN            1488.0
# 2 2020-04-03          -0.2372                   -0.2701            1393.0
# 3 2020-04-04          -0.3091                   -0.2638             915.0
# 4 2020-04-05          -0.2433                   -0.2633            1064.0
#
#    smoothed_articles_per_day  Covid Positive Rate  new_deaths_smoothed  \
# 0                        NaN                0.199              804.286
# 1                        NaN                0.204              966.000
# 2                  1263.3641                0.207             1095.429
# 3                  1177.0858                0.209             1225.000
# 4                  1129.2987                0.210             1377.571
#
#    weekly_hosp_admissions  new_vaccinations_smoothed  stringency_index
# 0                     NaN                        NaN             72.69
# 1                     NaN                        NaN             72.69
# 2                     NaN                        NaN             72.69
# 3                     NaN                        NaN             72.69
# 4                     NaN                        NaN             72.69

# %%
df.corr('spearman')
# Out:
#                            Sentiment Score  Smoothed Sentiment Score  \
# Sentiment Score                   1.000000                  0.949086
# Smoothed Sentiment Score          0.949086                  1.000000
# articles_per_day                 -0.295537                 -0.349496
# smoothed_articles_per_day        -0.383835                 -0.430781
# Covid Positive Rate              -0.519637                 -0.560677
# new_deaths_smoothed               0.098768                  0.091171
# weekly_hosp_admissions           -0.272546                 -0.299903
# new_vaccinations_smoothed         0.258707                  0.279188
# stringency_index                 -0.107038                 -0.118609
#
#                            articles_per_day  smoothed_articles_per_day  \
# Sentiment Score                   -0.295537                  -0.383835
# Smoothed Sentiment Score          -0.349496                  -0.430781
# articles_per_day                   1.000000                   0.942041
# smoothed_articles_per_day          0.942041                   1.000000
# Covid Positive Rate                0.552151                   0.620639
# new_deaths_smoothed                0.235571                   0.242987
# weekly_hosp_admissions             0.466620                   0.527153
# new_vaccinations_smoothed          0.373449                   0.371476
# stringency_index                   0.671182                   0.731462
#
#                            Covid Positive Rate  new_deaths_smoothed  \
# Sentiment Score                      -0.519637             0.098768
# Smoothed Sentiment Score             -0.560677             0.091171
# articles_per_day                      0.552151             0.235571
# smoothed_articles_per_day             0.620639             0.242987
# Covid Positive Rate                   1.000000             0.550325
# new_deaths_smoothed                   0.550325             1.000000
# weekly_hosp_admissions                0.886292             0.778069
# new_vaccinations_smoothed            -0.062612             0.012759
# stringency_index                      0.304971             0.228154
#
#                            weekly_hosp_admissions  new_vaccinations_smoothed  \
# Sentiment Score                         -0.272546                   0.258707
# Smoothed Sentiment Score                -0.299903                   0.279188
# articles_per_day                         0.466620                   0.373449
# smoothed_articles_per_day                0.527153                   0.371476
# Covid Positive Rate                      0.886292                  -0.062612
# new_deaths_smoothed                      0.778069                   0.012759
# weekly_hosp_admissions                   1.000000                   0.062069
# new_vaccinations_smoothed                0.062069                   1.000000
# stringency_index                         0.230056                   0.467742
#
#                            stringency_index
# Sentiment Score                   -0.107038
# Smoothed Sentiment Score          -0.118609
# articles_per_day                   0.671182
# smoothed_articles_per_day          0.731462
# Covid Positive Rate                0.304971
# new_deaths_smoothed                0.228154
# weekly_hosp_admissions             0.230056
# new_vaccinations_smoothed          0.467742
# stringency_index                   1.000000

# %%
df.to_csv("dashboard/covid_plot_data.csv")
