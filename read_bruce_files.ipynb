# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from striprtf.striprtf import rtf_to_text
import unicodedata

# %%
with open("/Users/gabrielnicholson/Downloads/bruce_files/Files(50) (1)/African Gold Mining Landscape Posturing for Changing Future; Players in the Game.rtf","r") as file:
    cc = file.read()
    text = rtf_to_text(cc).strip()
# text = text.strip().replace(u'\xa0', u' ')

# %%
unicodedata.normalize('NFKC', text)
# Out:
# 'African Gold Mining Landscape Posturing for Changing Future; Players in the Game\nInvestorIdeas.com\nMay 30, 2019 Thursday 1:05 PM EST\n\n\nCopyright 2019 Newstex LLC All Rights Reserved\nLength: 2147 words\nByline: Dawn Van Zant\nBody\n\n\nMay 30, 2019( InvestorIdeas.com: http://www.investorideas.com/ Delivered by Newstex)  Point Roberts, WA and Delta, BC - May 30, 2019 (Investorideas.com Newswire) Investorideas.com, a global investor news source covering mining stocks releases a snapshot looking at the recent developments in the African Gold mining sector, specifically in Tanzania. In Tanzania, revenues from the country\'s mineral resources are on the rise[1], thanks to government efforts to curb smuggling and strengthen the Mining Commission\'s capacity. The March 2017 government\'s decision to ban the export of mineral concentrates has led to increased mineral production and exports, and by March this year, the country had earned nearly $244 billion from minerals, representing 7
# ...
